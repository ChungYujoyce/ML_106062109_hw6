# %%
from random import seed
from random import randrange
from csv import reader
 

def loadDataset(dataset, data=[]):
    
    newdata = []
    for x in range(len(dataset)):
        for i in range(0,len(dataset[x]),4):
            if dataset[x][i] == "I":
                newdata.append(dataset[x][i:len(dataset[x])-1])
                break
            else:
                attribute = float(dataset[x][i:i+3])
                newdata.append(attribute)
            
        data.append(newdata)
        newdata=[] 

def cross_validation_split(dataset, n_folds):
	dataset_split = list()
	dataset_copy = list(dataset)
	fold_size = int(len(dataset) / n_folds)
	for i in range(n_folds):
		fold = list()
		while len(fold) < fold_size:
			index = randrange(len(dataset_copy))
			fold.append(dataset_copy.pop(index))
		dataset_split.append(fold)
	return dataset_split
 
# Calculate accuracy percentage
def accuracy_metric(actual, predicted):
	correct = 0
	for i in range(len(actual)):
		if actual[i] == predicted[i]:
			correct += 1
	return correct / float(len(actual)) * 100.0
 
# Evaluate an algorithm using a cross validation split
def evaluate_algorithm(dataset, algorithm, n_folds, *args):
	folds = cross_validation_split(dataset, n_folds)
	scores = list()
	for fold in folds:
		train_set = list(folds)
		train_set.remove(fold)
		train_set = sum(train_set, [])
		test_set = list()
		for row in fold:
			row_copy = list(row)
			test_set.append(row_copy)
			row_copy[-1] = None
		predicted = algorithm(train_set, test_set, *args)
		actual = [row[-1] for row in fold]
		accuracy = accuracy_metric(actual, predicted)
		scores.append(accuracy)
	return scores
 
# Make a prediction with weights
def predict(row, weights):
	activation = weights[0]
	for i in range(len(row)-1):
		activation += weights[i + 1] * row[i]
	return 1.0 if activation >= 0.0 else 0.0
 
# Estimate Perceptron weights using stochastic gradient descent
def train_weights(train, learning_rate, n_epoch):
    weights = [0.2 for i in range(len(train[0]))]
    for epoch in range(n_epoch):
        sum_error = 0.0
        for row in train:
            prediction = predict(row, weights)
            #print(prediction)
            error = row[-1] - prediction #list indices must be integers or slices, not list
            sum_error += error**2
            weights[0] = weights[0] + learning_rate * error
            for i in range(len(row)-1):
                weights[i+1] = weights[i+1] + learning_rate * error * row[i]
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, learning_rate, sum_error))
    print(weights)
    return weights 
 
# Perceptron Algorithm With Stochastic Gradient Descent
def perceptron(train, test, l_rate, n_epoch):
	predictions = list()
	weights = train_weights(train, l_rate, n_epoch)
	for row in test:
		prediction = predict(row, weights)
		predictions.append(prediction)
	return(predictions)
 
# Test the Perceptron algorithm on the sonar dataset
seed(1)
trainingSet=[]
testSet=[]

f = open('training-data.txt', "r")
train = f.readlines()
train = list(train)
f = open('testing-data.txt', "r")
test = f.readlines()
test = list(test)

loadDataset(train, trainingSet)
loadDataset(test, testSet)

for row in trainingSet:
    if row[-1] == "Iris-setosa":
        row.pop(-1)
        row.append(0)
    else:
        row.pop(-1)
        row.append(1)
        
for row in testSet:
    if row[-1] == "Iris-setosa":
        row.pop(-1)
        row.append(0)
    else:
        row.pop(-1)
        row.append(1)

n_folds = 9
l_rate = 0.2
n_epoch = 50
scores = evaluate_algorithm(trainingSet, perceptron, n_folds, l_rate, n_epoch)
print('Scores: %s' % scores)
print('Mean Accuracy: %.3f%%' % (sum(scores)/float(len(scores))))
# Out:
# >epoch=0, lrate=0.200, error=15.000
# >epoch=1, lrate=0.200, error=11.000
# >epoch=2, lrate=0.200, error=11.000
# >epoch=3, lrate=0.200, error=8.000
# >epoch=4, lrate=0.200, error=6.000
# >epoch=5, lrate=0.200, error=11.000
# >epoch=6, lrate=0.200, error=8.000
# >epoch=7, lrate=0.200, error=6.000
# >epoch=8, lrate=0.200, error=10.000
# >epoch=9, lrate=0.200, error=9.000
# >epoch=10, lrate=0.200, error=11.000
# >epoch=11, lrate=0.200, error=8.000
# >epoch=12, lrate=0.200, error=8.000
# >epoch=13, lrate=0.200, error=8.000
# >epoch=14, lrate=0.200, error=6.000
# >epoch=15, lrate=0.200, error=10.000
# >epoch=16, lrate=0.200, error=9.000
# >epoch=17, lrate=0.200, error=10.000
# >epoch=18, lrate=0.200, error=9.000
# >epoch=19, lrate=0.200, error=8.000
# >epoch=20, lrate=0.200, error=8.000
# >epoch=21, lrate=0.200, error=8.000
# >epoch=22, lrate=0.200, error=6.000
# >epoch=23, lrate=0.200, error=10.000
# >epoch=24, lrate=0.200, error=9.000
# >epoch=25, lrate=0.200, error=8.000
# >epoch=26, lrate=0.200, error=6.000
# >epoch=27, lrate=0.200, error=11.000
# >epoch=28, lrate=0.200, error=8.000
# >epoch=29, lrate=0.200, error=8.000
# >epoch=30, lrate=0.200, error=8.000
# >epoch=31, lrate=0.200, error=8.000
# >epoch=32, lrate=0.200, error=6.000
# >epoch=33, lrate=0.200, error=6.000
# >epoch=34, lrate=0.200, error=11.000
# >epoch=35, lrate=0.200, error=8.000
# >epoch=36, lrate=0.200, error=6.000
# >epoch=37, lrate=0.200, error=11.000
# >epoch=38, lrate=0.200, error=10.000
# >epoch=39, lrate=0.200, error=8.000
# >epoch=40, lrate=0.200, error=6.000
# >epoch=41, lrate=0.200, error=10.000
# >epoch=42, lrate=0.200, error=8.000
# >epoch=43, lrate=0.200, error=6.000
# >epoch=44, lrate=0.200, error=11.000
# >epoch=45, lrate=0.200, error=8.000
# >epoch=46, lrate=0.200, error=8.000
# >epoch=47, lrate=0.200, error=8.000
# >epoch=48, lrate=0.200, error=10.000
# >epoch=49, lrate=0.200, error=8.000
# [-2.4, -1.3800000000000001, -0.9399999999999938, 3.7599999999999874, 2.4199999999999955]
# >epoch=0, lrate=0.200, error=20.000
# >epoch=1, lrate=0.200, error=8.000
# >epoch=2, lrate=0.200, error=8.000
# >epoch=3, lrate=0.200, error=9.000
# >epoch=4, lrate=0.200, error=6.000
# >epoch=5, lrate=0.200, error=10.000
# >epoch=6, lrate=0.200, error=9.000
# >epoch=7, lrate=0.200, error=10.000
# >epoch=8, lrate=0.200, error=9.000
# >epoch=9, lrate=0.200, error=10.000
# >epoch=10, lrate=0.200, error=9.000
# >epoch=11, lrate=0.200, error=8.000
# >epoch=12, lrate=0.200, error=8.000
# >epoch=13, lrate=0.200, error=8.000
# >epoch=14, lrate=0.200, error=8.000
# >epoch=15, lrate=0.200, error=8.000
# >epoch=16, lrate=0.200, error=6.000
# >epoch=17, lrate=0.200, error=6.000
# >epoch=18, lrate=0.200, error=6.000
# >epoch=19, lrate=0.200, error=11.000
# >epoch=20, lrate=0.200, error=8.000
# >epoch=21, lrate=0.200, error=6.000
# >epoch=22, lrate=0.200, error=11.000
# >epoch=23, lrate=0.200, error=8.000
# >epoch=24, lrate=0.200, error=6.000
# >epoch=25, lrate=0.200, error=10.000
# >epoch=26, lrate=0.200, error=9.000
# >epoch=27, lrate=0.200, error=8.000
# >epoch=28, lrate=0.200, error=8.000
# >epoch=29, lrate=0.200, error=6.000
# >epoch=30, lrate=0.200, error=6.000
# >epoch=31, lrate=0.200, error=6.000
# >epoch=32, lrate=0.200, error=11.000
# >epoch=33, lrate=0.200, error=8.000
# >epoch=34, lrate=0.200, error=6.000
# >epoch=35, lrate=0.200, error=11.000
# >epoch=36, lrate=0.200, error=8.000
# >epoch=37, lrate=0.200, error=8.000
# >epoch=38, lrate=0.200, error=6.000
# >epoch=39, lrate=0.200, error=6.000
# >epoch=40, lrate=0.200, error=8.000
# >epoch=41, lrate=0.200, error=9.000
# >epoch=42, lrate=0.200, error=8.000
# >epoch=43, lrate=0.200, error=8.000
# >epoch=44, lrate=0.200, error=6.000
# >epoch=45, lrate=0.200, error=6.000
# >epoch=46, lrate=0.200, error=11.000
# >epoch=47, lrate=0.200, error=10.000
# >epoch=48, lrate=0.200, error=8.000
# >epoch=49, lrate=0.200, error=8.000
# [-2.4, -1.5800000000000027, -1.079999999999997, 3.0199999999999863, 3.319999999999995]
# >epoch=0, lrate=0.200, error=20.000
# >epoch=1, lrate=0.200, error=8.000
# >epoch=2, lrate=0.200, error=10.000
# >epoch=3, lrate=0.200, error=9.000
# >epoch=4, lrate=0.200, error=10.000
# >epoch=5, lrate=0.200, error=9.000
# >epoch=6, lrate=0.200, error=6.000
# >epoch=7, lrate=0.200, error=10.000
# >epoch=8, lrate=0.200, error=9.000
# >epoch=9, lrate=0.200, error=6.000
# >epoch=10, lrate=0.200, error=10.000
# >epoch=11, lrate=0.200, error=9.000
# >epoch=12, lrate=0.200, error=8.000
# >epoch=13, lrate=0.200, error=6.000
# >epoch=14, lrate=0.200, error=10.000
# >epoch=15, lrate=0.200, error=9.000
# >epoch=16, lrate=0.200, error=8.000
# >epoch=17, lrate=0.200, error=8.000
# >epoch=18, lrate=0.200, error=8.000
# >epoch=19, lrate=0.200, error=6.000
# >epoch=20, lrate=0.200, error=6.000
# >epoch=21, lrate=0.200, error=6.000
# >epoch=22, lrate=0.200, error=6.000
# >epoch=23, lrate=0.200, error=11.000
# >epoch=24, lrate=0.200, error=10.000
# >epoch=25, lrate=0.200, error=6.000
# >epoch=26, lrate=0.200, error=6.000
# >epoch=27, lrate=0.200, error=10.000
# >epoch=28, lrate=0.200, error=9.000
# >epoch=29, lrate=0.200, error=6.000
# >epoch=30, lrate=0.200, error=6.000
# >epoch=31, lrate=0.200, error=10.000
# >epoch=32, lrate=0.200, error=9.000
# >epoch=33, lrate=0.200, error=10.000
# >epoch=34, lrate=0.200, error=9.000
# >epoch=35, lrate=0.200, error=8.000
# >epoch=36, lrate=0.200, error=8.000
# >epoch=37, lrate=0.200, error=6.000
# >epoch=38, lrate=0.200, error=6.000
# >epoch=39, lrate=0.200, error=11.000
# >epoch=40, lrate=0.200, error=10.000
# >epoch=41, lrate=0.200, error=8.000
# >epoch=42, lrate=0.200, error=8.000
# >epoch=43, lrate=0.200, error=8.000
# >epoch=44, lrate=0.200, error=8.000
# >epoch=45, lrate=0.200, error=8.000
# >epoch=46, lrate=0.200, error=6.000
# >epoch=47, lrate=0.200, error=11.000
# >epoch=48, lrate=0.200, error=8.000
# >epoch=49, lrate=0.200, error=8.000
# [-2.4, -1.8600000000000014, -0.8599999999999933, 3.1199999999999886, 2.819999999999993]
# >epoch=0, lrate=0.200, error=16.000
# >epoch=1, lrate=0.200, error=8.000
# >epoch=2, lrate=0.200, error=7.000
# >epoch=3, lrate=0.200, error=8.000
# >epoch=4, lrate=0.200, error=4.000
# >epoch=5, lrate=0.200, error=4.000
# >epoch=6, lrate=0.200, error=4.000
# >epoch=7, lrate=0.200, error=4.000
# >epoch=8, lrate=0.200, error=4.000
# >epoch=9, lrate=0.200, error=4.000
# >epoch=10, lrate=0.200, error=6.000
# >epoch=11, lrate=0.200, error=7.000
# >epoch=12, lrate=0.200, error=4.000
# >epoch=13, lrate=0.200, error=4.000
# >epoch=14, lrate=0.200, error=4.000
# >epoch=15, lrate=0.200, error=6.000
# >epoch=16, lrate=0.200, error=4.000
# >epoch=17, lrate=0.200, error=4.000
# >epoch=18, lrate=0.200, error=4.000
# >epoch=19, lrate=0.200, error=4.000
# >epoch=20, lrate=0.200, error=7.000
# >epoch=21, lrate=0.200, error=4.000
# >epoch=22, lrate=0.200, error=4.000
# >epoch=23, lrate=0.200, error=6.000
# >epoch=24, lrate=0.200, error=4.000
# >epoch=25, lrate=0.200, error=4.000
# >epoch=26, lrate=0.200, error=6.000
# >epoch=27, lrate=0.200, error=4.000
# >epoch=28, lrate=0.200, error=4.000
# >epoch=29, lrate=0.200, error=4.000
# >epoch=30, lrate=0.200, error=4.000
# >epoch=31, lrate=0.200, error=4.000
# >epoch=32, lrate=0.200, error=4.000
# >epoch=33, lrate=0.200, error=5.000
# >epoch=34, lrate=0.200, error=4.000
# >epoch=35, lrate=0.200, error=6.000
# >epoch=36, lrate=0.200, error=4.000
# >epoch=37, lrate=0.200, error=4.000
# >epoch=38, lrate=0.200, error=4.000
# >epoch=39, lrate=0.200, error=6.000
# >epoch=40, lrate=0.200, error=4.000
# >epoch=41, lrate=0.200, error=5.000
# >epoch=42, lrate=0.200, error=6.000
# >epoch=43, lrate=0.200, error=4.000
# >epoch=44, lrate=0.200, error=6.000
# >epoch=45, lrate=0.200, error=4.000
# >epoch=46, lrate=0.200, error=5.000
# >epoch=47, lrate=0.200, error=4.000
# >epoch=48, lrate=0.200, error=4.000
# >epoch=49, lrate=0.200, error=6.000
# [-1.4, -3.6199999999999948, 0.5200000000000022, 5.679999999999997, 1.5000000000000009]
# >epoch=0, lrate=0.200, error=20.000
# >epoch=1, lrate=0.200, error=8.000
# >epoch=2, lrate=0.200, error=6.000
# >epoch=3, lrate=0.200, error=8.000
# >epoch=4, lrate=0.200, error=11.000
# >epoch=5, lrate=0.200, error=8.000
# >epoch=6, lrate=0.200, error=6.000
# >epoch=7, lrate=0.200, error=6.000
# >epoch=8, lrate=0.200, error=8.000
# >epoch=9, lrate=0.200, error=8.000
# >epoch=10, lrate=0.200, error=11.000
# >epoch=11, lrate=0.200, error=6.000
# >epoch=12, lrate=0.200, error=6.000
# >epoch=13, lrate=0.200, error=6.000
# >epoch=14, lrate=0.200, error=8.000
# >epoch=15, lrate=0.200, error=11.000
# >epoch=16, lrate=0.200, error=10.000
# >epoch=17, lrate=0.200, error=6.000
# >epoch=18, lrate=0.200, error=6.000
# >epoch=19, lrate=0.200, error=8.000
# >epoch=20, lrate=0.200, error=8.000
# >epoch=21, lrate=0.200, error=8.000
# >epoch=22, lrate=0.200, error=11.000
# >epoch=23, lrate=0.200, error=8.000
# >epoch=24, lrate=0.200, error=6.000
# >epoch=25, lrate=0.200, error=6.000
# >epoch=26, lrate=0.200, error=8.000
# >epoch=27, lrate=0.200, error=11.000
# >epoch=28, lrate=0.200, error=10.000
# >epoch=29, lrate=0.200, error=6.000
# >epoch=30, lrate=0.200, error=6.000
# >epoch=31, lrate=0.200, error=8.000
# >epoch=32, lrate=0.200, error=8.000
# >epoch=33, lrate=0.200, error=11.000
# >epoch=34, lrate=0.200, error=6.000
# >epoch=35, lrate=0.200, error=6.000
# >epoch=36, lrate=0.200, error=6.000
# >epoch=37, lrate=0.200, error=8.000
# >epoch=38, lrate=0.200, error=8.000
# >epoch=39, lrate=0.200, error=11.000
# >epoch=40, lrate=0.200, error=8.000
# >epoch=41, lrate=0.200, error=6.000
# >epoch=42, lrate=0.200, error=6.000
# >epoch=43, lrate=0.200, error=6.000
# >epoch=44, lrate=0.200, error=6.000
# >epoch=45, lrate=0.200, error=8.000
# >epoch=46, lrate=0.200, error=11.000
# >epoch=47, lrate=0.200, error=10.000
# >epoch=48, lrate=0.200, error=6.000
# >epoch=49, lrate=0.200, error=6.000
# [-1.7999999999999998, -0.8600000000000014, -0.45999999999999797, 1.7399999999999958, 3.9999999999999982]
# >epoch=0, lrate=0.200, error=11.000
# >epoch=1, lrate=0.200, error=11.000
# >epoch=2, lrate=0.200, error=6.000
# >epoch=3, lrate=0.200, error=4.000
# >epoch=4, lrate=0.200, error=4.000
# >epoch=5, lrate=0.200, error=6.000
# >epoch=6, lrate=0.200, error=4.000
# >epoch=7, lrate=0.200, error=4.000
# >epoch=8, lrate=0.200, error=6.000
# >epoch=9, lrate=0.200, error=9.000
# >epoch=10, lrate=0.200, error=4.000
# >epoch=11, lrate=0.200, error=6.000
# >epoch=12, lrate=0.200, error=4.000
# >epoch=13, lrate=0.200, error=6.000
# >epoch=14, lrate=0.200, error=4.000
# >epoch=15, lrate=0.200, error=4.000
# >epoch=16, lrate=0.200, error=6.000
# >epoch=17, lrate=0.200, error=11.000
# >epoch=18, lrate=0.200, error=6.000
# >epoch=19, lrate=0.200, error=4.000
# >epoch=20, lrate=0.200, error=6.000
# >epoch=21, lrate=0.200, error=4.000
# >epoch=22, lrate=0.200, error=4.000
# >epoch=23, lrate=0.200, error=4.000
# >epoch=24, lrate=0.200, error=6.000
# >epoch=25, lrate=0.200, error=4.000
# >epoch=26, lrate=0.200, error=4.000
# >epoch=27, lrate=0.200, error=13.000
# >epoch=28, lrate=0.200, error=6.000
# >epoch=29, lrate=0.200, error=4.000
# >epoch=30, lrate=0.200, error=6.000
# >epoch=31, lrate=0.200, error=4.000
# >epoch=32, lrate=0.200, error=4.000
# >epoch=33, lrate=0.200, error=6.000
# >epoch=34, lrate=0.200, error=4.000
# >epoch=35, lrate=0.200, error=4.000
# >epoch=36, lrate=0.200, error=6.000
# >epoch=37, lrate=0.200, error=4.000
# >epoch=38, lrate=0.200, error=4.000
# >epoch=39, lrate=0.200, error=6.000
# >epoch=40, lrate=0.200, error=11.000
# >epoch=41, lrate=0.200, error=6.000
# >epoch=42, lrate=0.200, error=4.000
# >epoch=43, lrate=0.200, error=6.000
# >epoch=44, lrate=0.200, error=4.000
# >epoch=45, lrate=0.200, error=6.000
# >epoch=46, lrate=0.200, error=4.000
# >epoch=47, lrate=0.200, error=4.000
# >epoch=48, lrate=0.200, error=6.000
# >epoch=49, lrate=0.200, error=4.000
# [-1.0, -1.2399999999999962, -0.6999999999999991, 2.2200000000000037, 3.2800000000000007]
# >epoch=0, lrate=0.200, error=13.000
# >epoch=1, lrate=0.200, error=11.000
# >epoch=2, lrate=0.200, error=9.000
# >epoch=3, lrate=0.200, error=8.000
# >epoch=4, lrate=0.200, error=6.000
# >epoch=5, lrate=0.200, error=9.000
# >epoch=6, lrate=0.200, error=8.000
# >epoch=7, lrate=0.200, error=6.000
# >epoch=8, lrate=0.200, error=8.000
# >epoch=9, lrate=0.200, error=7.000
# >epoch=10, lrate=0.200, error=4.000
# >epoch=11, lrate=0.200, error=6.000
# >epoch=12, lrate=0.200, error=8.000
# >epoch=13, lrate=0.200, error=6.000
# >epoch=14, lrate=0.200, error=6.000
# >epoch=15, lrate=0.200, error=7.000
# >epoch=16, lrate=0.200, error=6.000
# >epoch=17, lrate=0.200, error=6.000
# >epoch=18, lrate=0.200, error=6.000
# >epoch=19, lrate=0.200, error=8.000
# >epoch=20, lrate=0.200, error=6.000
# >epoch=21, lrate=0.200, error=6.000
# >epoch=22, lrate=0.200, error=7.000
# >epoch=23, lrate=0.200, error=6.000
# >epoch=24, lrate=0.200, error=6.000
# >epoch=25, lrate=0.200, error=6.000
# >epoch=26, lrate=0.200, error=6.000
# >epoch=27, lrate=0.200, error=8.000
# >epoch=28, lrate=0.200, error=6.000
# >epoch=29, lrate=0.200, error=6.000
# >epoch=30, lrate=0.200, error=6.000
# >epoch=31, lrate=0.200, error=4.000
# >epoch=32, lrate=0.200, error=9.000
# >epoch=33, lrate=0.200, error=6.000
# >epoch=34, lrate=0.200, error=6.000
# >epoch=35, lrate=0.200, error=6.000
# >epoch=36, lrate=0.200, error=9.000
# >epoch=37, lrate=0.200, error=6.000
# >epoch=38, lrate=0.200, error=6.000
# >epoch=39, lrate=0.200, error=7.000
# >epoch=40, lrate=0.200, error=6.000
# >epoch=41, lrate=0.200, error=6.000
# >epoch=42, lrate=0.200, error=6.000
# >epoch=43, lrate=0.200, error=6.000
# >epoch=44, lrate=0.200, error=8.000
# >epoch=45, lrate=0.200, error=6.000
# >epoch=46, lrate=0.200, error=6.000
# >epoch=47, lrate=0.200, error=5.000
# >epoch=48, lrate=0.200, error=6.000
# >epoch=49, lrate=0.200, error=6.000
# [-1.9999999999999998, -3.0999999999999943, -0.09999999999999887, 4.819999999999985, 1.6000000000000032]
# >epoch=0, lrate=0.200, error=13.000
# >epoch=1, lrate=0.200, error=11.000
# >epoch=2, lrate=0.200, error=11.000
# >epoch=3, lrate=0.200, error=8.000
# >epoch=4, lrate=0.200, error=9.000
# >epoch=5, lrate=0.200, error=6.000
# >epoch=6, lrate=0.200, error=8.000
# >epoch=7, lrate=0.200, error=9.000
# >epoch=8, lrate=0.200, error=6.000
# >epoch=9, lrate=0.200, error=8.000
# >epoch=10, lrate=0.200, error=11.000
# >epoch=11, lrate=0.200, error=8.000
# >epoch=12, lrate=0.200, error=9.000
# >epoch=13, lrate=0.200, error=8.000
# >epoch=14, lrate=0.200, error=7.000
# >epoch=15, lrate=0.200, error=8.000
# >epoch=16, lrate=0.200, error=6.000
# >epoch=17, lrate=0.200, error=8.000
# >epoch=18, lrate=0.200, error=8.000
# >epoch=19, lrate=0.200, error=9.000
# >epoch=20, lrate=0.200, error=8.000
# >epoch=21, lrate=0.200, error=9.000
# >epoch=22, lrate=0.200, error=7.000
# >epoch=23, lrate=0.200, error=6.000
# >epoch=24, lrate=0.200, error=9.000
# >epoch=25, lrate=0.200, error=6.000
# >epoch=26, lrate=0.200, error=6.000
# >epoch=27, lrate=0.200, error=8.000
# >epoch=28, lrate=0.200, error=7.000
# >epoch=29, lrate=0.200, error=8.000
# >epoch=30, lrate=0.200, error=8.000
# >epoch=31, lrate=0.200, error=10.000
# >epoch=32, lrate=0.200, error=6.000
# >epoch=33, lrate=0.200, error=6.000
# >epoch=34, lrate=0.200, error=8.000
# >epoch=35, lrate=0.200, error=9.000
# >epoch=36, lrate=0.200, error=7.000
# >epoch=37, lrate=0.200, error=9.000
# >epoch=38, lrate=0.200, error=8.000
# >epoch=39, lrate=0.200, error=8.000
# >epoch=40, lrate=0.200, error=7.000
# >epoch=41, lrate=0.200, error=9.000
# >epoch=42, lrate=0.200, error=8.000
# >epoch=43, lrate=0.200, error=8.000
# >epoch=44, lrate=0.200, error=7.000
# >epoch=45, lrate=0.200, error=9.000
# >epoch=46, lrate=0.200, error=8.000
# >epoch=47, lrate=0.200, error=8.000
# >epoch=48, lrate=0.200, error=7.000
# >epoch=49, lrate=0.200, error=9.000
# [-2.1999999999999997, -0.6400000000000045, -2.0999999999999908, 1.6799999999999984, 4.179999999999976]
# >epoch=0, lrate=0.200, error=15.000
# >epoch=1, lrate=0.200, error=13.000
# >epoch=2, lrate=0.200, error=9.000
# >epoch=3, lrate=0.200, error=6.000
# >epoch=4, lrate=0.200, error=11.000
# >epoch=5, lrate=0.200, error=8.000
# >epoch=6, lrate=0.200, error=8.000
# >epoch=7, lrate=0.200, error=9.000
# >epoch=8, lrate=0.200, error=6.000
# >epoch=9, lrate=0.200, error=10.000
# >epoch=10, lrate=0.200, error=9.000
# >epoch=11, lrate=0.200, error=6.000
# >epoch=12, lrate=0.200, error=8.000
# >epoch=13, lrate=0.200, error=9.000
# >epoch=14, lrate=0.200, error=6.000
# >epoch=15, lrate=0.200, error=10.000
# >epoch=16, lrate=0.200, error=9.000
# >epoch=17, lrate=0.200, error=6.000
# >epoch=18, lrate=0.200, error=6.000
# >epoch=19, lrate=0.200, error=8.000
# >epoch=20, lrate=0.200, error=10.000
# >epoch=21, lrate=0.200, error=9.000
# >epoch=22, lrate=0.200, error=6.000
# >epoch=23, lrate=0.200, error=6.000
# >epoch=24, lrate=0.200, error=6.000
# >epoch=25, lrate=0.200, error=10.000
# >epoch=26, lrate=0.200, error=9.000
# >epoch=27, lrate=0.200, error=6.000
# >epoch=28, lrate=0.200, error=6.000
# >epoch=29, lrate=0.200, error=8.000
# >epoch=30, lrate=0.200, error=10.000
# >epoch=31, lrate=0.200, error=9.000
# >epoch=32, lrate=0.200, error=6.000
# >epoch=33, lrate=0.200, error=6.000
# >epoch=34, lrate=0.200, error=8.000
# >epoch=35, lrate=0.200, error=10.000
# >epoch=36, lrate=0.200, error=9.000
# >epoch=37, lrate=0.200, error=10.000
# >epoch=38, lrate=0.200, error=8.000
# >epoch=39, lrate=0.200, error=10.000
# >epoch=40, lrate=0.200, error=8.000
# >epoch=41, lrate=0.200, error=7.000
# >epoch=42, lrate=0.200, error=9.000
# >epoch=43, lrate=0.200, error=7.000
# >epoch=44, lrate=0.200, error=8.000
# >epoch=45, lrate=0.200, error=8.000
# >epoch=46, lrate=0.200, error=6.000
# >epoch=47, lrate=0.200, error=6.000
# >epoch=48, lrate=0.200, error=6.000
# >epoch=49, lrate=0.200, error=11.000
# [-2.6, -2.2600000000000007, -0.17999999999999594, 2.7399999999999904, 3.8399999999999874]
# Scores: [100.0, 90.0, 90.0, 90.0, 100.0, 80.0, 90.0, 90.0, 90.0]
# Mean Accuracy: 91.111%
